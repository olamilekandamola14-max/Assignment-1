# %%
#print function
print("Hello world")
print("Welcome to Data Analysis")
print("Welcome to python programming")
print(32)
print(4.12)
# Out:
# Hello world
# Welcome to Data Analysis
# Welcome to python programming
# 32
# 4.12

# %%
# Variables
name = "Alice"
age = 30
height = 6
is_student = False

print(name)
print(age)

print("My name is", name) # comma seperation method

print("I am", age, "years old")

# Rules governing naming variables
# 1. There will be no empty space in a variable

# is student = False
# describe what it stores
# no hyphen is-student = False
# you cannot start a variable with a number 1st_name = "Alice"
# Out:
# Alice
# 30
# My name is Alice
# I am 30 years old

# %%
# Data types
price = 30.56
name = 'Alice'
age = 30
is_student = False

# %%
print(type(name))
print(type(age))
print(type(is_student))
type(price)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# float

# %%
# working with strings

message = "Hello, Python!"
name = 'Alice'
# print(message, name)

#concatenation
first_name = "John"
last_name = "Doe"
full_name = first_name + " " + last_name 
print(full_name)

# String repetition
laugh = "ha"
print(laugh * 5)
# Out:
# John Doe
# hahahahaha

# %%
# formatted string/ f-strings
print(f"My name is {name} and i am {age} years old")

price = 100
print(f"price with tax is ${price * 1.25}")
# Out:
# My name is Alice and i am 30 years old
# price with tax is $125.0

# %%
# string operations

text = "Python Programming"
print(text.upper())
print(text.lower())
print(text.replace("Python", "Java"))
print(len(text))
# Out:
# PYTHON PROGRAMMING
# python programming
# Java Programming
# 18

# %%
# multi-line string
poem = """twinkle twinkle little stars
How i wonder what you are
Up above the world so high
Like a diamond in the sky
"""
print(poem)
# Out:
# twinkle twinkle little stars
# How i wonder what you are
# Up above the world so high
# Like a diamond in the sky

# %%
# multi-line string
poem = "twinkle twinkle little stars.\n How i wonder what you are,\n Up above the world so high,\n Like a diamond in the sky"
print(poem)
# Out:
# twinkle twinkle little stars.
#  How i wonder what you are,
#  Up above the world so high,
#  Like a diamond in the sky

# %% [markdown]
# # EXERCISE 2.2: Personal Introduction
# # Create a formatted introduction using f-strings
# # Include: name, city, favorite hobby
